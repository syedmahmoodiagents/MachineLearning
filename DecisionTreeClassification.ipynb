# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/MachineLearning/blob/main/DecisionTreeClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
dt = load_iris()

# %%
dt.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
x = dt.data

# %%
y = dt.target

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mod = DecisionTreeClassifier()

# %%
mod.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
mod.feature_importances_
# Out:
# array([0.01333333, 0.01333333, 0.55072262, 0.42261071])

# %%
X = x[:, 2:]

# %%
# !pip install mglearn --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 9.3 MB/s eta 0:00:00

# %%
import mglearn as mg

# %%
mg.discrete_scatter(x1=X[:,0], x2=X[:,1], y=y)

# %%
mod1 = DecisionTreeClassifier()

# %%
mod1.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
mg.discrete_scatter(x1=X[:,0], x2=X[:,1], y=y)
mg.plots.plot_2d_separator(mod1, X)

# %%
mod2 = DecisionTreeClassifier(max_depth=2, criterion='entropy')
mod2.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
mg.discrete_scatter(x1=X[:,0], x2=X[:,1], y=y)
mg.plots.plot_2d_separator(mod2, X)

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mod2)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4090909090909091, 0.75, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.4545454545454546, 0.8333333333333333, 'True  '),
#  Text(0.5909090909090909, 0.75, 'x[1] <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5454545454545454, 0.8333333333333333, '  False'),
#  Text(0.36363636363636365, 0.5833333333333334, 'x[0] <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.18181818181818182, 0.4166666666666667, 'x[1] <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.09090909090909091, 0.25, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.2727272727272727, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5454545454545454, 0.4166666666666667, 'x[1] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
# ...
