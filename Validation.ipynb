# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/MachineLearning/blob/main/Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mglearn --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 12.4 MB/s eta 0:00:00

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_iris

# %%
dt = load_iris()

# %%
dt.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X = dt.data
Y = dt.target

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model= DecisionTreeClassifier()

# %%
model.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X, Y)
# Out:
# 1.0

# %% [markdown]
# # Lets use train test split

# %%
list('abcdefghij')
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
list('1234567890')
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']

# %%
train_test_split(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
# Out:
# [['g', 'e', 'c', 'f', 'h', 'i', 'j'],
#  ['b', 'a', 'd'],
#  ['g', 'e', 'c', 'f', 'h', 'i', 'j'],
#  ['b', 'a', 'd']]

# %%
BigX,smallx,BigY,smally = train_test_split(X,Y, random_state=0)

# %%
BigX.shape, smallx.shape
# Out:
# ((112, 4), (38, 4))

# %%
model.fit(BigX, BigY)

# %%
Xtrain,xtest,Ytrain,ytest = train_test_split(X,Y, random_state=1)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Ytrain_p = model.predict(Xtrain)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Ytrain, Ytrain_p)
# Out:
# 1.0

# %%
ytest_p = model.predict(xtest)

# %%
accuracy_score(ytest, ytest_p)
# Out:
# 0.9736842105263158

# %%
# Make Moons

# %%
from sklearn.datasets import make_moons

# %%
X, Y = make_moons(noise=0.15, random_state=0)

# %%
import mglearn as mg

# %%
mg.discrete_scatter(X[:,0], X[:,1], Y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,Y, random_state=0)

# %%
modl = DecisionTreeClassifier(max_depth=2)

# %%
modl.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
yp_train = modl.predict(xtrain)

# %%
yp_test = modl.predict(xtest)

# %%
accuracy_score(ytrain, yp_train)
# Out:
# 0.9466666666666667

# %%
accuracy_score(ytest, yp_test)
# Out:
# 0.88
