# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/MachineLearning/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs

# %%
import matplotlib.pyplot as plt

# %%
X,_ = make_blobs(centers=5, cluster_std=1, random_state=1)

# %%
x, y = X[:,0], X[:,1]

# %%
plt.scatter(x,y)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
mdltr = DecisionTreeRegressor(max_depth=2)

# %%
xx = x.reshape(-1,1)

# %%
mdltr.fit(xx,y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
yp = mdltr.predict(xx)

# %%
plt.scatter(x, y)
plt.scatter(x, yp)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(y,yp)
# Out:
# 0.9303729244771735

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
modl = RandomForestRegressor(max_depth=3)

# %%
modl.fit(xx,y)
# Out:
# RandomForestRegressor(max_depth=3)

# %%
ypp = modl.predict(xx)

# %%
plt.scatter(x,y)
plt.scatter(xx,ypp)
